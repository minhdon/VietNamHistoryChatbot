# %%
import pandas as pd
df=pd.read_parquet("./data/process/dataset_final_graphrag.parquet")
df.head()
# Out:
#                                               system  \
# 0  Bạn là một trợ lý AI am hiểu về lịch sử Việt N...
# 1  Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# 2  Bạn là một trợ lý AI am hiểu về lịch sử Việt N...
# 3  Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# 4  Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
#
#                                                 user  \
# 0  Nguyễn Huệ (Quang Trung) đã làm gì để dẫn đến ...
# 1  Kể về Gia Long (Nguyễn Ánh) và đóng góp của ôn...
# 2  Năm 1527 ở Việt Nam diễn ra sự kiện gì quan tr...
# 3  Trình bày nhanh những điểm chính về Ký kết CPTPP.
# 4  Hậu quả hay tác động dài hạn của Đại Việt đánh...
#
#                                            assistant  \
# 0  Bối cảnh: Ngọc Hồi – Đống Đa (Quang Trung) thu...
# 1  Câu hỏi nhắm tới sự kiện Nguyễn Ánh lên ngôi G...
# 2  Bối cảnh: Mạc Đăng Dung lập nhà Mạc thuộc Nhà ...
# 3  Để trả lời: Ký kết CPTPP diễn ra năm 2018. Nội...
# ...

# %%
df
# Out:
#                                                   system  \
# 0      Bạn là một trợ lý AI am hiểu về lịch sử Việt N...
# 1      Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# 2      Bạn là một trợ lý AI am hiểu về lịch sử Việt N...
# 3      Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# 4      Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# ...                                                  ...
# 21938  Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# 21939  Bạn là trợ lý lịch sử Việt Nam. Hãy giải thích...
# 21940  Bạn là chuyên gia sử học Việt Nam. Có thể nêu ...
# 21941  Bạn là một trợ lý AI am hiểu về lịch sử Việt N...
# 21942  Bạn là một trợ lý AI am hiểu về lịch sử Việt N...
#
#                                                     user  \
# 0      Nguyễn Huệ (Quang Trung) đã làm gì để dẫn đến ...
# 1      Kể về Gia Long (Nguyễn Ánh) và đóng góp của ôn...
# 2      Năm 1527 ở Việt Nam diễn ra sự kiện gì quan tr...
# ...
