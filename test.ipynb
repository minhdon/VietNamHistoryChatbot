# %%
import pandas as pd
df=pd.read_parquet("data/vectorDatabase/dataset_with_embeddings.parquet")
df
# Out:
#                   id                                               text  \
# 0            chunk_0  Hỏi: Tóm tắt Hòa ước Patenôtre (Giáp Thân) và ...
# 1            chunk_1  Hỏi: Hãy cho biết sự kiện tiêu biểu của Việt N...
# 2            chunk_2  Hỏi: Tóm tắt Nhà Trần thành lập và nêu ý nghĩa...
# 3            chunk_3  Hỏi: Kể tên và tóm tắt sự kiện nổi bật ở Việt ...
# 4            chunk_4  Hỏi: Hãy mô tả ngắn gọn bối cảnh và ý nghĩa củ...
# ...              ...                                                ...
# 999995  chunk_999995  Hỏi: Năm 1941 ở Việt Nam diễn ra sự kiện gì qu...
# 999996  chunk_999996  Hỏi: Giải thích vì sao Dương Đình Nghệ đánh ta...
# 999997  chunk_999997  Hỏi: Hậu quả hay tác động dài hạn của Tổng tiế...
# 999998  chunk_999998  Hỏi: Hãy cho biết sự kiện tiêu biểu của Việt N...
# 999999  chunk_999999  Hỏi: Trong năm 931, điều gì có ý nghĩa lịch sử...
#
#                                                 embedding
# ...
